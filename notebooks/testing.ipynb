# %%
import librosa as lb
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# %%
y, sr = lb.load('../data/testing/De la Habana.wav')

# %%
D = lb.stft(y)
# y = np.Array(y)
S_db = lb.amplitude_to_db(np.abs(D), ref=np.max)

# %%
fig, ax = plt.subplots()
D_highres = librosa.stft(y, hop_length=256, n_fft=4096)
S_db_hr = librosa.amplitude_to_db(np.abs(D_highres), ref=np.max)
img = librosa.display.specshow(S_db_hr, hop_length=256, x_axis='time', y_axis='log', ax=ax)
fig.colorbar(img, ax=ax, format="%+2.f dB")
